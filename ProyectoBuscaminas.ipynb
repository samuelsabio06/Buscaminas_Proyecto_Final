# %%
import random

def crear_tablero(filas, columnas):
    # Crear el tablero
    tablero = [['*' for _ in range(columnas)] for _ in range(filas)]
    return tablero

def mostrar_tablero(tablero):
    print(" ", end="")  # Espacio inicial para alinear los números de las columnas
    for u in range(len(tablero[0])):  # Imprimir los números de las columnas
        print(u, end="")
    print()

    for i in range(len(tablero)):
        print(i , end="")  # Imprimir el número de la fila
        for j in range(len(tablero[0])):
            print(tablero[i][j], end="")  # Imprimir los elementos de la fila
        print()


def crear_minas(filas,columnas,dificultad):
    match dificultad:
      case 1.0:
          dificultad = 0.10
      case 2.0:
          dificultad = 0.15
      case 3.0:
          dificultad = 0.25

    minas = [[1 if random.random() < dificultad else 0 for _ in range(columnas)] for _ in range(filas)]
    return minas

def calcular_fondo(minas):
    fondo = [[0 for _ in range(len(minas[0]))] for _ in range(len(minas))]

    for i in range(len(minas)):
        for j in range(len(minas[0])):
            if minas[i][j] == 1: fondo[i][j] = 'X'
            else:
                for k in range(max(0, i-1), min(len(minas), i+2)):
                    for l in range(max(0, j-1), min(len(minas[0]), j+2)):
                        fondo[i][j] += minas[k][l]
    return fondo

def jugar(tablero, fondo):
    while True:
        try:
            fila = int(input("Introduce la fila: "))
            columna = int(input("Introduce la columna: "))
        except ValueError:
            print("Por favor introduce un número válido.")
            continue

        if fila < 0 or fila >= len(tablero) or columna < 0 or columna >= len(tablero[0]):
            print("Coordenadas fuera de los límites del tablero.")
            continue

        if fondo[fila][columna] == 'X':
            print("MINA ENCOTRADA. ¡Juego terminado!")
            tablero[fila][columna] = 'X'
            mostrar_tablero(tablero)
            break
        else:
            tablero[fila][columna] = str(fondo[fila][columna])
            mostrar_tablero(tablero)
            print("Sigue jugando.")

def main():
    # Solicitar al usuario el tamaño de la tablero
    try:
        filas = int(input("Introduce el número de filas: "))
        columnas = int(input("Introduce el número de columnas: "))
        dificultad = float(input("Ingrese la dificultad del juego \n1. Fácil \n2. Heroica \n3. Legendaria\n"))
    except ValueError:
        print("Por favor introduce un número válido.")


    # Crear y mostrar la tablero
    tablero = crear_tablero(filas, columnas)
    mostrar_tablero(tablero)

    #Generar las minas
    minas = crear_minas(filas,columnas,dificultad)

    #Calcular los valores del fondo cubierto según las minas
    fondo = calcular_fondo(minas)
    #mostrar_tablero(fondo) #temporal

    #Empezar el juego
    jugar(tablero, fondo)


if __name__ == "__main__":
    main()
# Out:
# Introduce el número de filas: 8
# Introduce el número de columnas: 8
# Ingrese la dificultad del juego
# 1. Fácil
# 2. Heroica
# 3. Legendaria
# 3
#  01234567
# 0********
# 1********
# 2********
# 3********
# 4********
# 5********
# 6********
# 7********
# Introduce la fila: 1
# Introduce la columna: 5
#  01234567
# 0********
# 1*****2**
# 2********
# 3********
# 4********
# 5********
# 6********
# 7********
# Sigue jugando.
# Introduce la fila: 2
# Introduce la columna: 2
# MINA ENCOTRADA. ¡Juego terminado!
#  01234567
# 0********
# 1*****2**
# 2**X*****
# 3********
# 4********
# 5********
# 6********
# 7********
